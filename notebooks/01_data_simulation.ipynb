# %% [markdown]
# # 01 - Data Simulation
# This notebook explains the simulated healthcare MMM dataset.

# %%
import pandas as pd
from pathlib import Path
DATA = Path('../data/processed/healthcare_lead_gen_weekly_mmm.csv')
df = pd.read_csv(DATA, parse_dates=['week_start'])
df.head()

# %%
df.describe().T

# %% [markdown]
# The dataset includes 104 weekly observations, four media channels, controls, qualified calls and appointment bookings.
