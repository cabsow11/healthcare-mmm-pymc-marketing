# %% [markdown]
# # 02 - EDA and Validation
# Inspect channel dynamics, spend correlation, seasonality and tracking quality.

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
DATA = Path('../data/processed/healthcare_lead_gen_weekly_mmm.csv')
df = pd.read_csv(DATA, parse_dates=['week_start'])

# %%
channels = ['google_search_spend','meta_spend','youtube_spend','display_spend']
df[channels].corr()

# %%
df[['week_start','qualified_calls','total_media_spend','tracking_quality_index']].tail(15)
