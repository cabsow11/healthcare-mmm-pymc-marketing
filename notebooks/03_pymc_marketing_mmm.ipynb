# %% [markdown]
# # 03 - PyMC-Marketing MMM
# Template notebook for fitting the MMM in the client's SageMaker container.

# %%
import pandas as pd
from pathlib import Path
DATA = Path('../data/processed/healthcare_lead_gen_weekly_mmm.csv')
df = pd.read_csv(DATA, parse_dates=['week_start'])

# %%
from src.pymc_marketing_reference import build_pymc_marketing_mmm
# mmm, X, y = build_pymc_marketing_mmm(df)
# idata = mmm.fit(X=X, y=y, draws=1000, tune=1000, chains=4, target_accept=0.9)

# %% [markdown]
# The exact PyMC-Marketing keyword interface should be verified against the installed package version in SageMaker.
