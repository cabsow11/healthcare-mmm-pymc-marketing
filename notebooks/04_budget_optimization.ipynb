# %% [markdown]
# # 04 - Budget Optimization
# Review ROI, mROAS and conservative reallocation logic.

# %%
import pandas as pd
roi = pd.read_csv('../outputs/channel_roi_summary.csv')
budget = pd.read_csv('../outputs/budget_recommendation.csv')
roi

# %%
budget
